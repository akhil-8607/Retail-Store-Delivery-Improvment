# %%
from google.colab import files
from sklearn import preprocessing
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
import io
kfold = KFold(n_splits=5, shuffle=True)
def finalm():
	fm = Sequential()
	fm.add(Dense(22, input_dim=22, activation='relu'))
	fm.add(Dense(10, activation='softmax'))
	fm.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return fm
data = files.upload()
df2 = pd.read_csv(io.BytesIO(data['question2data.csv']))
dataset = df2.values
smimx = preprocessing.MinMaxScaler()
s_x = smimx.fit_transform(dataset)
df = pd.DataFrame(s_x)
fval = df.values
X = fval[: , 0:22]
Y = fval[:, 22:33]

pred = KerasClassifier(build_fn=finalm, epochs=200, batch_size=5, verbose=0)
results = cross_val_score(pred, X, Y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
#      <input type="file" id="files-54f132e0-2525-4088-8ff3-f5ee1079b93d" name="files[]" multiple disabled />
#      <output id="result-54f132e0-2525-4088-8ff3-f5ee1079b93d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving question2data.csv to question2data.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-133acd94401e> in <module>()
#      29
#      30 pred = KerasClassifier(build_fn=finalm, epochs=200, batch_size=5, verbose=0)
# ---> 31 results = cross_val_score(pred, X, Y, cv=kfold)
#      32 print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
#      33
#
# ...
